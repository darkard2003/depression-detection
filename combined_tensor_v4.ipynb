# %%
# !ls processed
# Out:
# X_combined_sparse.npz     X_tfidf.npz
# X_nrc_features_scaled.npy y.npy

# %%
data_dir='processed_dirty'
X_combined_dataset_sparse_file='X_combined_sparse.npz'
y_sampled_file='y.npy'

# %%
import numpy as np
from os import path
from scipy.sparse import load_npz
import pandas as pd

X_combined_dataset = load_npz(path.join(data_dir, X_combined_dataset_sparse_file))
y_resampled=np.load(path.join(data_dir, y_sampled_file))
y_resampled=pd.Series(y_resampled)

# %%
from sklearn.model_selection import train_test_split

X_train_val, X_test, y_train_val, y_test = train_test_split(X_combined_dataset, y_resampled, test_size=0.2, stratify=y_resampled, random_state=42)

print(f'X_train shape: {X_train_val.shape}')
print(f'y_train shape: {y_train_val.shape}')
print(f'X_test shape: {X_test.shape}')
print(f'y_test shape: {y_test.shape}')

print(f'y_train count:\n{y_train_val.value_counts()}')
print(f'y_test count:\n{y_test.value_counts()}')
# Out:
# X_train shape: (79672, 5010)
# y_train shape: (79672,)
# X_test shape: (19918, 5010)
# y_test shape: (19918,)
# y_train count:
# 0    46724
# 1    32948
# Name: count, dtype: int64
# y_test count:
# 0    11681
# 1     8237
# Name: count, dtype: int64

# %%
import numpy as np
from os import path
from scipy.sparse import load_npz
import pandas as pd
import tensorflow as tf

class SparseDataGenerator(tf.keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, x, y, batch_size=32, shuffle=True, **kwargs): # Added shuffle
        super().__init__(**kwargs)
        'Initialization'
        self.batch_size = batch_size
        self.x = x
        self.y = y
        self.shuffle = shuffle # Store shuffle preference

        # --- FIX 1: Use .shape[0] ---
        self.indexes = np.arange(self.x.shape[0])

        # --- FIX 3: Add on_epoch_end and call it ---
        self.on_epoch_end() # Perform initial shuffle

    def __len__(self):
        'Denotes the number of batches per epoch'
        # --- FIX for inconsistent sample count: return ceil of division to include last batch ---
        return int(np.ceil(self.x.shape[0] / self.batch_size))


    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        # --- FIX for inconsistent sample count: adjust slicing for the last batch ---
        start_index = index * self.batch_size
        end_index = min((index + 1) * self.batch_size, self.x.shape[0])
        indexes = self.indexes[start_index:end_index]


        # Find list of IDs
        x_batch_sparse = self.x[indexes]
        y_batch = self.y[indexes]

        # --- FIX 2: THIS IS THE MOST IMPORTANT LINE ---
        # It solves your RAM problem by only converting the small batch
        x_batch_dense = x_batch_sparse.toarray()
        # (Using .toarray() is generally preferred over .todense())

        return x_batch_dense, y_batch

    # --- FIX 3: Added this required method ---
    def on_epoch_end(self):
        'Updates indexes after each epoch'
        if self.shuffle:
            np.random.shuffle(self.indexes)

# %%
from imblearn.over_sampling import RandomOverSampler
from sklearn.model_selection import train_test_split

# Split first to avoid leakage from duplicated samples entering validation.
X_train, X_val, y_train, y_val = train_test_split(
    X_train_val, y_train_val, test_size=0.2, stratify=y_train_val, random_state=42
)

ros = RandomOverSampler(random_state=42)
X_train_resampled, y_train_resampled = ros.fit_resample(X_train, y_train)

# Resample full train+val only for final retraining after model selection.
X_train_val_resampled, y_train_val_resampled = ros.fit_resample(X_train_val, y_train_val)

print(f'X_train_resampled shape: {X_train_resampled.shape}')
print(f'y_train_resampled shape: {y_train_resampled.shape}')
print(f'y_train_resampled count:\n{y_train_resampled.value_counts()}')
# Out:
# X_train_resampled shape: (74758, 5010)
# y_train_resampled shape: (74758,)
# y_train_resampled count:
# 0    37379
# 1    37379
# Name: count, dtype: int64

# %%
# Convert pandas Series to numpy arrays for consistent indexing in the generator
train_generator = SparseDataGenerator(X_train_resampled, y_train_resampled.to_numpy(), batch_size=32)
test_generator = SparseDataGenerator(X_test, y_test.to_numpy(), batch_size=32, shuffle=False)
val_generator = SparseDataGenerator(X_val, y_val.to_numpy(), batch_size=32, shuffle=False)
train_val_generator = SparseDataGenerator(X_train_val_resampled, y_train_val_resampled.to_numpy(), batch_size=32)

# %%
from tensorflow import keras
from tensorflow.keras import layers

def build_model(hp):
    model = keras.Sequential()
    model.add(layers.Input(shape=(X_train.shape[1],)))  # Input layer matching the number of features

    l2_reg = hp.Float('l2_reg', min_value=1e-5, max_value=1e-3, sampling='log')

    # Add number of layers between 1 and 3
    for i in range(hp.Int('num_layers', min_value=1, max_value=3)):
        model.add(
            layers.Dense(
                units=hp.Int(f'units_hidden_{i}', min_value=32, max_value=512, step=32),
                activation=hp.Choice(f'activation_hidden_{i}', values=['relu', 'tanh']),
                kernel_regularizer=keras.regularizers.l2(l2_reg)
            )
        )
        model.add(layers.Dropout(rate=hp.Float(f'dropout_{i}', min_value=0.0, max_value=0.5, step=0.1)))

    # Output layer
    model.add(layers.Dense(1, activation='sigmoid'))

    optimizer_choice = hp.Choice('optimizer', values=['adam', 'rmsprop'])
    learning_rate = hp.Float('learning_rate', min_value=1e-4, max_value=1e-2, sampling='log')
    if optimizer_choice == 'adam':
        optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
    else:
        optimizer = keras.optimizers.RMSprop(learning_rate=learning_rate)

    model.compile(
        optimizer=optimizer,
        loss='binary_crossentropy',
        metrics=[
            'accuracy',
            keras.metrics.AUC(name='auc'),
            keras.metrics.AUC(curve='PR', name='pr_auc')
        ]
    )
    return model

# %%
from keras_tuner import Hyperband
import keras_tuner as kt

PROJECT_NAME='reddit_mlp_hyperband_v4'
tuner = Hyperband(
    build_model,
    objective=kt.Objective('val_pr_auc', direction='max'),
    max_epochs=20,
    factor=3,
    directory='keras_mlp',
    project_name=PROJECT_NAME,
    overwrite=False
 )

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

tuner.search(train_generator, epochs=20, validation_data=val_generator, callbacks=[early_stopping])
# Out:
# Trial 30 Complete [00h 05m 15s]
# val_pr_auc: 0.8797335624694824
#
# Best val_pr_auc So Far: 0.9405317902565002
# Total elapsed time: 02h 00m 00s

# %%
# Get the best hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

# Build the model with the best hyperparameters
model = build_model(best_hps)

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                 │ (None, 320)            │     1,603,520 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 320)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 32)             │        10,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 96)             │         3,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 96)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            97 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,617,057 (6.17 MB)
#  Trainable params: 1,617,057 (6.17 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
import matplotlib.pyplot as plt
from sklearn.utils import class_weight

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True
)


# Train the model with the best hyperparameters to get the training history
# Use the generators for training and validation
history = model.fit(
    train_generator,
    epochs=200,
    validation_data=val_generator,
    callbacks=[early_stop],
)

# Plot training & validation accuracy values
plt.figure(figsize=(12, 6))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# Out:
# Epoch 1/200
# 2337/2337 ━━━━━━━━━━━━━━━━━━━━ 48s 20ms/step - accuracy: 0.8386 - auc: 0.9029 - loss: 0.4386 - pr_auc: 0.8863 - val_accuracy: 0.8511 - val_auc: 0.9173 - val_loss: 0.4016 - val_pr_auc: 0.8729
# Epoch 2/200
# 2337/2337 ━━━━━━━━━━━━━━━━━━━━ 46s 20ms/step - accuracy: 0.8612 - auc: 0.9215 - loss: 0.3892 - pr_auc: 0.9066 - val_accuracy: 0.8570 - val_auc: 0.9234 - val_loss: 0.3861 - val_pr_auc: 0.8836
# Epoch 3/200
# 2337/2337 ━━━━━━━━━━━━━━━━━━━━ 45s 19ms/step - accuracy: 0.8764 - auc: 0.9409 - loss: 0.3388 - pr_auc: 0.9362 - val_accuracy: 0.8773 - val_auc: 0.9474 - val_loss: 0.3226 - val_pr_auc: 0.9281
# Epoch 4/200
# 2337/2337 ━━━━━━━━━━━━━━━━━━━━ 46s 20ms/step - accuracy: 0.8875 - auc: 0.9531 - loss: 0.3050 - pr_auc: 0.9507 - val_accuracy: 0.8788 - val_auc: 0.9511 - val_loss: 0.3180 - val_pr_auc: 0.9349
# Epoch 5/200
# 2337/2337 ━━━━━━━━━━━━━━━━━━━━ 46s 20ms/step - accuracy: 0.8944 - auc: 0.9573 - loss: 0.2917 - pr_auc: 0.9557 - val_accuracy: 0.8850 - val_auc: 0.9525 - val_loss: 0.3040 - val_pr_auc: 0.9366
# Epoch 6/200
# 2337/2337 ━━━━━━━━━━━━━━━━━━━━ 46s 20ms/step - accuracy: 0.8967 - auc: 0.9597 - loss: 0.2844 - pr_auc: 0.9589 - val_accuracy: 0.8803 - val_auc: 0.9533 - val_loss: 0.3147 - val_pr_auc: 0.9382
# Epoch 7/200
# 2337/2337 ━━━━━━━━━━━━━━━━━━━━ 45s 19ms/step - accuracy: 0.8989 - auc: 0.9607 - loss: 0.2811 - pr_auc: 0.9598 - val_accuracy: 0.8897 - val_auc: 0.9538 - val_loss: 0.3005 - val_pr_auc: 0.9391
# Epoch 8/200
# 2337/2337 ━━━━━━━━━━━━━━━━━━━━ 45s 19ms/step - accuracy: 0.8997 - auc: 0.9618 - loss: 0.2788 - pr_auc: 0.9604 - val_accuracy: 0.8891 - val_auc: 0.9543 - val_loss: 0.3000 - val_pr_auc: 0.9394
# Epoch 9/200
# 2337/2337 ━━━━━━━━━━━━━━━━━━━━ 47s 20ms/step - accuracy: 0.9006 - auc: 0.9624 - loss: 0.2773 - pr_auc: 0.9614 - val_accuracy: 0.8904 - val_auc: 0.9537 - val_loss: 0.3051 - val_pr_auc: 0.9375
# Epoch 10/200
# 2337/2337 ━━━━━━━━━━━━━━━━━━━━ 48s 20ms/step - accuracy: 0.9000 - auc: 0.9629 - loss: 0.2769 - pr_auc: 0.9617 - val_accuracy: 0.8921 - val_auc: 0.9545 - val_loss: 0.3024 - val_pr_auc: 0.9389
# Epoch 11/200
# 2337/2337 ━━━━━━━━━━━━━━━━━━━━ 43s 18ms/step - accuracy: 0.9026 - auc: 0.9632 - loss: 0.2766 - pr_auc: 0.9619 - val_accuracy: 0.8889 - val_auc: 0.9550 - val_loss: 0.3025 - val_pr_auc: 0.9396
# Epoch 12/200
# 2337/2337 ━━━━━━━━━━━━━━━━━━━━ 42s 18ms/step - accuracy: 0.9023 - auc: 0.9636 - loss: 0.2765 - pr_auc: 0.9625 - val_accuracy: 0.8871 - val_auc: 0.9550 - val_loss: 0.3117 - val_pr_auc: 0.9384
# Epoch 13/200
# 2337/2337 ━━━━━━━━━━━━━━━━━━━━ 41s 17ms/step - accuracy: 0.9033 - auc: 0.9636 - loss: 0.2770 - pr_auc: 0.9622 - val_accuracy: 0.8905 - val_auc: 0.9558 - val_loss: 0.3035 - val_pr_auc: 0.9398
# Epoch 14/200
# 2337/2337 ━━━━━━━━━━━━━━━━━━━━ 41s 17ms/step - accuracy: 0.9041 - auc: 0.9644 - loss: 0.2751 - pr_auc: 0.9633 - val_accuracy: 0.8919 - val_auc: 0.9561 - val_loss: 0.3028 - val_pr_auc: 0.9403
# Epoch 15/200
# 2337/2337 ━━━━━━━━━━━━━━━━━━━━ 40s 17ms/step - accuracy: 0.9037 - auc: 0.9645 - loss: 0.2751 - pr_auc: 0.9635 - val_accuracy: 0.8885 - val_auc: 0.9560 - val_loss: 0.3082 - val_pr_auc: 0.9399
# Epoch 16/200
# 2337/2337 ━━━━━━━━━━━━━━━━━━━━ 41s 17ms/step - accuracy: 0.9043 - auc: 0.9649 - loss: 0.2740 - pr_auc: 0.9639 - val_accuracy: 0.8914 - val_auc: 0.9562 - val_loss: 0.3051 - val_pr_auc: 0.9406
# Epoch 17/200
# 2337/2337 ━━━━━━━━━━━━━━━━━━━━ 41s 17ms/step - accuracy: 0.9049 - auc: 0.9653 - loss: 0.2734 - pr_auc: 0.9645 - val_accuracy: 0.8919 - val_auc: 0.9567 - val_loss: 0.2988 - val_pr_auc: 0.9415
# Epoch 18/200
# 2337/2337 ━━━━━━━━━━━━━━━━━━━━ 40s 17ms/step - accuracy: 0.9044 - auc: 0.9654 - loss: 0.2731 - pr_auc: 0.9646 - val_accuracy: 0.8888 - val_auc: 0.9565 - val_loss: 0.3066 - val_pr_auc: 0.9405
# Epoch 19/200
# 2337/2337 ━━━━━━━━━━━━━━━━━━━━ 41s 18ms/step - accuracy: 0.9053 - auc: 0.9657 - loss: 0.2720 - pr_auc: 0.9645 - val_accuracy: 0.8921 - val_auc: 0.9564 - val_loss: 0.3000 - val_pr_auc: 0.9411
# Epoch 20/200
# 2337/2337 ━━━━━━━━━━━━━━━━━━━━ 41s 17ms/step - accuracy: 0.9060 - auc: 0.9660 - loss: 0.2713 - pr_auc: 0.9652 - val_accuracy: 0.8924 - val_auc: 0.9574 - val_loss: 0.2975 - val_pr_auc: 0.9422
# Epoch 21/200
# 2337/2337 ━━━━━━━━━━━━━━━━━━━━ 41s 17ms/step - accuracy: 0.9058 - auc: 0.9659 - loss: 0.2715 - pr_auc: 0.9653 - val_accuracy: 0.8873 - val_auc: 0.9569 - val_loss: 0.3089 - val_pr_auc: 0.9407
# Epoch 22/200
# 2337/2337 ━━━━━━━━━━━━━━━━━━━━ 42s 18ms/step - accuracy: 0.9074 - auc: 0.9659 - loss: 0.2714 - pr_auc: 0.9648 - val_accuracy: 0.8882 - val_auc: 0.9567 - val_loss: 0.3045 - val_pr_auc: 0.9403
# Epoch 23/200
# 2337/2337 ━━━━━━━━━━━━━━━━━━━━ 42s 18ms/step - accuracy: 0.9070 - auc: 0.9662 - loss: 0.2707 - pr_auc: 0.9652 - val_accuracy: 0.8924 - val_auc: 0.9567 - val_loss: 0.3008 - val_pr_auc: 0.9408
# Epoch 24/200
# 2337/2337 ━━━━━━━━━━━━━━━━━━━━ 41s 18ms/step - accuracy: 0.9051 - auc: 0.9661 - loss: 0.2713 - pr_auc: 0.9652 - val_accuracy: 0.8911 - val_auc: 0.9564 - val_loss: 0.2999 - val_pr_auc: 0.9418
# Epoch 25/200
# 2337/2337 ━━━━━━━━━━━━━━━━━━━━ 42s 18ms/step - accuracy: 0.9059 - auc: 0.9662 - loss: 0.2708 - pr_auc: 0.9655 - val_accuracy: 0.8930 - val_auc: 0.9569 - val_loss: 0.3011 - val_pr_auc: 0.9420
# Epoch 26/200
# 2337/2337 ━━━━━━━━━━━━━━━━━━━━ 42s 18ms/step - accuracy: 0.9055 - auc: 0.9657 - loss: 0.2725 - pr_auc: 0.9643 - val_accuracy: 0.8918 - val_auc: 0.9568 - val_loss: 0.3008 - val_pr_auc: 0.9412
# Epoch 27/200
# 2337/2337 ━━━━━━━━━━━━━━━━━━━━ 43s 18ms/step - accuracy: 0.9058 - auc: 0.9659 - loss: 0.2718 - pr_auc: 0.9648 - val_accuracy: 0.8894 - val_auc: 0.9570 - val_loss: 0.3062 - val_pr_auc: 0.9408
# Epoch 28/200
# 2337/2337 ━━━━━━━━━━━━━━━━━━━━ 42s 18ms/step - accuracy: 0.9060 - auc: 0.9662 - loss: 0.2705 - pr_auc: 0.9650 - val_accuracy: 0.8916 - val_auc: 0.9570 - val_loss: 0.3024 - val_pr_auc: 0.9412
# Epoch 29/200
# 2337/2337 ━━━━━━━━━━━━━━━━━━━━ 41s 17ms/step - accuracy: 0.9063 - auc: 0.9663 - loss: 0.2704 - pr_auc: 0.9653 - val_accuracy: 0.8909 - val_auc: 0.9572 - val_loss: 0.3009 - val_pr_auc: 0.9421
# Epoch 30/200
# 2337/2337 ━━━━━━━━━━━━━━━━━━━━ 39s 17ms/step - accuracy: 0.9066 - auc: 0.9660 - loss: 0.2714 - pr_auc: 0.9651 - val_accuracy: 0.8912 - val_auc: 0.9572 - val_loss: 0.3017 - val_pr_auc: 0.9421

# %%
# Tune decision threshold on validation set to optimize F1.
from sklearn.metrics import f1_score

val_probs = model.predict(val_generator).ravel()
threshold_grid = np.linspace(0.1, 0.9, 81)
f1_scores = [f1_score(y_val, (val_probs >= t).astype(int)) for t in threshold_grid]
best_threshold = float(threshold_grid[int(np.argmax(f1_scores))])

print(f'Best validation threshold (F1): {best_threshold:.3f}')
print(f'Best validation F1: {max(f1_scores):.4f}')
# Out:
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Best validation threshold (F1): 0.440
# Best validation F1: 0.8730

# %%
best_epoch_num = np.argmin(history.history['val_loss']) + 1

print(f'Best epoch found: {best_epoch_num}')

final_model = build_model(best_hps)


final_model.fit(train_val_generator, epochs=best_epoch_num, verbose=True)
# Out:
# Best epoch found: 8
# Epoch 1/8
# /Users/dark/code/project/depression/.venv/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 2921/2921 ━━━━━━━━━━━━━━━━━━━━ 36s 12ms/step - accuracy: 0.8461 - auc: 0.9125 - loss: 0.3802 - pr_auc: 0.8980
# Epoch 2/8
# 2921/2921 ━━━━━━━━━━━━━━━━━━━━ 32s 11ms/step - accuracy: 0.8724 - auc: 0.9351 - loss: 0.3228 - pr_auc: 0.9247
# Epoch 3/8
# 2921/2921 ━━━━━━━━━━━━━━━━━━━━ 30s 10ms/step - accuracy: 0.8934 - auc: 0.9571 - loss: 0.2652 - pr_auc: 0.9547
# Epoch 4/8
# 2921/2921 ━━━━━━━━━━━━━━━━━━━━ 30s 10ms/step - accuracy: 0.9024 - auc: 0.9640 - loss: 0.2431 - pr_auc: 0.9626
# Epoch 5/8
# 2921/2921 ━━━━━━━━━━━━━━━━━━━━ 31s 11ms/step - accuracy: 0.9108 - auc: 0.9693 - loss: 0.2236 - pr_auc: 0.9690
# Epoch 6/8
# 2921/2921 ━━━━━━━━━━━━━━━━━━━━ 30s 10ms/step - accuracy: 0.9165 - auc: 0.9731 - loss: 0.2095 - pr_auc: 0.9728
# Epoch 7/8
# 2921/2921 ━━━━━━━━━━━━━━━━━━━━ 31s 11ms/step - accuracy: 0.9216 - auc: 0.9757 - loss: 0.1989 - pr_auc: 0.9756
# Epoch 8/8
# 2921/2921 ━━━━━━━━━━━━━━━━━━━━ 31s 11ms/step - accuracy: 0.9253 - auc: 0.9776 - loss: 0.1906 - pr_auc: 0.9773

# %%
# Evaluate the final retrained model on the test data.
loss, accuracy, auc, pr_auc = final_model.evaluate(
    SparseDataGenerator(X_test, y_test.to_numpy(), batch_size=32, shuffle=False)
 )

print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")
print(f"Test ROC-AUC: {auc:.4f}")
print(f"Test PR-AUC: {pr_auc:.4f}")
# Out:
# 623/623 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8929 - auc: 0.9602 - loss: 0.2614 - pr_auc: 0.9455
# Test Loss: 0.2614
# Test Accuracy: 0.8929
# Test ROC-AUC: 0.9602
# Test PR-AUC: 0.9455

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Get predictions on the test set using the final retrained model.
y_pred_probs = final_model.predict(
    SparseDataGenerator(X_test, y_test.to_numpy(), batch_size=32, shuffle=False)
).ravel()
y_pred = (y_pred_probs >= best_threshold).astype("int32")

print("Classification Report:")
print(classification_report(y_test, y_pred))

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['0', '1'], yticklabels=['0', '1'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 104/623 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# /Users/dark/code/project/depression/.venv/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 623/623 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.88      0.90     11681
#            1       0.84      0.91      0.87      8237
#
#     accuracy                           0.89     19918
#    macro avg       0.89      0.89      0.89     19918
# weighted avg       0.89      0.89      0.89     19918

# %%
from sklearn.metrics import roc_curve, auc

# Calculate ROC curve and AUC
fpr, tpr, thresholds = roc_curve(y_test, y_pred_probs)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %%
# Calculate PR curve and Average Precision
from sklearn.metrics import precision_recall_curve, average_precision_score
precision, recall, _ = precision_recall_curve(y_test, y_pred_probs)
average_precision = average_precision_score(y_test, y_pred_probs)

# Plot PR curve
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, color='blue', lw=2, label='PR curve (area = %0.2f)' % average_precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower left")
plt.show()

# %%
import os
model_directory='models'
if not os.path.exists(model_directory):
    os.makedirs(model_directory)
model_name=f'{PROJECT_NAME}_weighted.keras'
final_model.save(path.join(model_directory, model_name))
